# %%
# Working with Strings

# %%
Name = "Michael Jackson"

# %%
# Obtain letter in Sequence

# %%
Name[5]
# Out:
# 'e'

# %%
Name[-5]
# Out:
# 'c'

# %%
# Obtain "Mich" from Name

# %%
Name[0:4]
# Out:
# 'Mich'

# %%
# Obtain "Jack" from Name

# %%
Name[8:12]
# Out:
# 'Jack'

# %%
# Length of Name

# %%
len(Name)
# Out:
# 15

# %%
# Creating  a statement

# %%
Name + " is the best"
# Out:
# 'Michael Jackson is the best'

# %%
# Make a String uppercase

# %%
A= "Thriller was a popular song"

# %%
B=A.upper()

# %%
B
# Out:
# 'THRILLER WAS A POPULAR SONG'

# %%
# Replace a name with another name

# %%
B=A.replace('Thriller', 'Beat It')

# %%
B
# Out:
# 'Beat It was a popular song'
